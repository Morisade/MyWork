# %%
import pandas as pd

# %%
df = pd.read_csv("/content/amazon_products_sales_data_cleaned.csv")
df
# Out:
#                                            product_title  product_rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...             4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...             4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...             4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...             4.8
# ...                                                  ...             ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...             5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...             4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...             4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...             4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...             4.4
#
#        total_reviews  purchased_last_month  discounted_price  original_price  \
# ...

# %%
df.shape
# Out:
# (42675, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   product_title         42675 non-null  object
#  1   product_rating        41651 non-null  float64
#  2   total_reviews         41651 non-null  float64
#  3   purchased_last_month  32164 non-null  float64
#  4   discounted_price      40613 non-null  float64
#  5   original_price        40613 non-null  float64
#  6   is_best_seller        42675 non-null  object
#  7   is_sponsored          42675 non-null  object
#  8   has_coupon            42675 non-null  object
#  9   buy_box_availability  28022 non-null  object
#  10  delivery_date         30692 non-null  object
#  11  sustainability_tags   3408 non-null   object
#  12  product_image_url     42675 non-null  object
#  13  product_page_url      40606 non-null  object
# ...

# %%
df.describe()
# Out:
#        product_rating  total_reviews  purchased_last_month  discounted_price  \
# count    41651.000000   41651.000000          32164.000000      40613.000000
# mean         4.399431    3087.106000           1293.665278        243.227289
# std          0.386997   13030.460133           6318.323574        473.351545
# min          1.000000       1.000000             50.000000          2.160000
# 25%          4.200000      82.000000            100.000000         29.690000
# 50%          4.500000     343.000000            200.000000         84.990000
# 75%          4.700000    1886.000000            400.000000        224.000000
# max          5.000000  865598.000000         100000.000000       5449.000000
#
#        original_price  discount_percentage
# count    40613.000000         40613.000000
# mean       257.611107             6.547151
# std        496.633495            12.744715
# min          2.160000             0.000000
# 25%         32.990000             0.000000
# ...

# %%
#What kind of information do we have about the Amazon sales dataset?
#What columns do we have? 17 columns Can you already understand the data from the column names? Yes
#How many rows does each column have? 42672 Are there any missing data? yes Why does it matter to know about the missing data? so as to know the rows with null values or incomplete information
#Are all row values integers? Yes  Are there any categorical values present?#

# %%
df.head(5)
# Out:
#                                        product_title  product_rating  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...             4.3
# 2  DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...             4.6
# 3  Apple AirPods Pro 2 Wireless Earbuds, Active N...             4.6
# 4  Apple AirTag 4 Pack. Keep Track of and find Yo...             4.8
#
#    total_reviews  purchased_last_month  discounted_price  original_price  \
# 0          375.0                 300.0             89.68          159.00
# 1         2457.0                6000.0              9.99           15.99
# 2         3044.0                2000.0            314.00          349.00
# 3        35882.0               10000.0            162.24          162.24
# 4        28988.0               10000.0             72.74           72.74
#
#   is_best_seller is_sponsored             has_coupon buy_box_availability  \
# ...

# %%
df_sorted=df.sort_values(by=["product_rating","original_price"], ascending=False)
df_sorted
# Out:
#                                            product_title  product_rating  \
# 9975   Logitech Rally bar and tap IP Bundle, 1920 Pix...             5.0
# 9695   Sony Alpha FX3 Full-Frame Cinema Line Camera B...             5.0
# 10386  Sony Alpha FX3 Full-Frame Cinema Line Camera B...             5.0
# 7847                                Sony FE 50-150 F2 GM             5.0
# 8744                                Sony FE 50-150 F2 GM             5.0
# ...                                                  ...             ...
# 29188  Duracell PGD MN27BPK Electronic Watch Battery,...             NaN
# 30465  Duracell PGD MN27BPK Electronic Watch Battery,...             NaN
# 854    Buffalo Games - Gold - Eric Dowdle - Golden Ga...             NaN
# 10903  ASURION 3 Year B2B Office Equipment Protection...             NaN
# 15909  Energizer EN55-12IT, 12 Volt 55 Amp Hr, Long L...             NaN
#
#        total_reviews  purchased_last_month  discounted_price  original_price  \
# ...

# %%
df_sorted_reset_index=df_sorted.reset_index()
df_sorted_reset_index
# Out:
#        index                                      product_title  \
# 0       9975  Logitech Rally bar and tap IP Bundle, 1920 Pix...
# 1       9695  Sony Alpha FX3 Full-Frame Cinema Line Camera B...
# 2      10386  Sony Alpha FX3 Full-Frame Cinema Line Camera B...
# 3       7847                               Sony FE 50-150 F2 GM
# 4       8744                               Sony FE 50-150 F2 GM
# ...      ...                                                ...
# 42670  29188  Duracell PGD MN27BPK Electronic Watch Battery,...
# 42671  30465  Duracell PGD MN27BPK Electronic Watch Battery,...
# 42672    854  Buffalo Games - Gold - Eric Dowdle - Golden Ga...
# 42673  10903  ASURION 3 Year B2B Office Equipment Protection...
# 42674  15909  Energizer EN55-12IT, 12 Volt 55 Amp Hr, Long L...
#
#        product_rating  total_reviews  purchased_last_month  discounted_price  \
# 0                 5.0            1.0                   NaN           4699.00
# ...

# %% [markdown]
# **Task 7: Reset Index with .reset_index() after sorting the purchased_last_month values descending with .sort_values(). Drop the column with the old indices. Make sure to save the resetted df into a new variable**

# %%
#What is the mean price of the products?
df_mean_prices = df_sorted_reset_index['original_price'].mean()
print(df_mean_prices)
# Out:
# 257.61110703469336

# %%
df_mean_prices = df_sorted_reset_index['discounted_price'].mean()
df_mean_prices
# Out:
# np.float64(243.22728929160616)

# %%
df_min_prices = df_sorted_reset_index['original_price'].min()
df_min_prices
# Out:
# 2.16

# %%
df_max_prices = df_sorted_reset_index['original_price'].max()
df_max_prices
# Out:
# 5449.0

# %%
df
# Out:
#                                            product_title  product_rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...             4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...             4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...             4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...             4.8
# ...                                                  ...             ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...             5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...             4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...             4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...             4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...             4.4
#
#        total_reviews  purchased_last_month  discounted_price  original_price  \
# ...

# %%
df.product_category.unique()
# Out:
# array(['Phones', 'Laptops', 'Other Electronics', 'Cameras', 'Storage',
#        'Printers & Scanners', 'TV & Display', 'Power & Batteries',
#        'Chargers & Cables', 'Headphones', 'Networking', 'Speakers',
#        'Wearables', 'Gaming', 'Smart Home'], dtype=object)

# %%
df.product_title.unique()
# Out:
# array(['BOYA BOYALINK 2 Wireless Lavalier Microphone for iPhone Camera Android, Mini Lapel Micophone Wireless, 48 KHz 24 Bit, 6mm Mic, 1000ft, 30h Use, Noise Cancelling, Clip on Mic USB-C/Lightning/3.5mm TRS',
#        'LISEN USB C to Lightning Cable, 240W 4 in 1 Charging Cable 6.6FT, Chubby USB A/C to C/Lightning with Light for iPhone 16e 15 14 Pro/MacBook Air 17/iPad/Samsung/Switch 2, Multi Chargers for All Devices',
#        'DJI Mic 2 (2 TX + 1 RX + Charging Case), Wireless Lavalier Microphone, Intelligent Noise Cancelling, 32-bit Float Internal Recording, 820 ft.(250m) Range, Microphone for iPhone, Android, Camera',
#        ...,
#        'Monster Clarity 8.0 Hybrid Active Noise Cancelling Wireless Earbuds, 42dB in-Ear ANC Earphones Deep Bass with 6 Mics, Bluetooth 5.2, 50H Play Time with Wireless Charging Case,Blue',
#        'Audio-Technica HP-EP Replacement Ear Pads for M Series Headphones',
# ...

# %%
df.head(3)
# Out:
#                                        product_title  product_rating  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...             4.3
# 2  DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...             4.6
#
#    total_reviews  purchased_last_month  discounted_price  original_price  \
# 0          375.0                 300.0             89.68          159.00
# 1         2457.0                6000.0              9.99           15.99
# 2         3044.0                2000.0            314.00          349.00
#
#   is_best_seller is_sponsored             has_coupon buy_box_availability  \
# 0       No Badge    Sponsored  Save 15%  with coupon          Add to cart
# 1       No Badge    Sponsored              No Coupon          Add to cart
# 2       No Badge    Sponsored              No Coupon          Add to cart
#
#   delivery_date sustainability_tags  \
# 0    2025-09-01       Carbon impact
# ...

# %%
df.is_sponsored.value_counts()
# Out:
# is_sponsored
# Organic      35664
# Sponsored     7011
# Name: count, dtype: int64

# %%
df.is_best_seller.value_counts()
# Out:
# is_best_seller
# No Badge             40814
# Amazon's               744
# Limited time deal      409
# Best Seller            275
# Save 30%               125
# Ends in                 97
# Save 10%                61
# Save 18%                57
# Save 17%                51
# Save 12%                26
# Save 9%                 14
# Save 77%                 2
# Name: count, dtype: int64

# %%
df1= df.product_category.value_counts()
df1
# Out:
# product_category
# Other Electronics      8755
# Laptops                8693
# Phones                 6563
# Cameras                3677
# Power & Batteries      2877
# TV & Display           2630
# Chargers & Cables      1833
# Storage                1630
# Speakers               1345
# Networking             1070
# Headphones              997
# Printers & Scanners     877
# Gaming                  809
# Smart Home              465
# Wearables               454
# Name: count, dtype: int64

# %%
df_value_count = df[['is_best_seller','product_category']].apply(pd.value_counts)
# Out:
# /tmp/ipython-input-2476667218.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   df_value_count = df[['is_best_seller','product_category']].apply(pd.value_counts)
# /tmp/ipython-input-2476667218.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   df_value_count = df[['is_best_seller','product_category']].apply(pd.value_counts)

# %%
df1.plot.bar()
# Out:
# <Axes: xlabel='product_category'>

# %%
df1.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df.original_price.idxmax()
# Out:
# 6858

# %%
df.original_price.idxmin()
# Out:
# 4349
